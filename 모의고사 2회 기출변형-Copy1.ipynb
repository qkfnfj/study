# %% [markdown]
# # 2회 기출 변형

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 작업 1유형

# %% [markdown]
# ```{attention}
# 데이터설명 : 보스턴집값, 각 행은 지역구별 집값관련된 메타정보 : https://www.kaggle.com/datasets/arunjathari/bostonhousepricedata
# **DataUrl = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv**
# ```

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv')
df
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  NaN   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731  NaN   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729  NaN   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237  NaN   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905  0.0   2.18     0  0.458    NaN  54.2  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ```{admonition} 1-1
# 주어진 Dataset에서 CRIM값이 가장 큰 10개의 지역을 구하고
# 10개의 지역의 CRIM값을 그 중 가장 작은 값으로 대체하라. 그리고
# AGE 컬럼 값이 80이상인 대체 된 CRIM 평균값을 구하라
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv')

df = df.sort_values(['CRIM'],ascending=False)
df2 = df.copy()
df2 = df2.head(10)
dm  = df2['CRIM'].min()
# dm

df['CRIM'] = np.where(df['CRIM']>dm,dm,df['CRIM'])
df
df = df[df['AGE']>=80]
print(df['CRIM'].mean())
# Out:
# 5.759386625
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 380  25.94060  0.0  18.10     0  0.671  6.968   91.9  1.4165   24  666.0
# 418  25.94060  0.0  18.10     0  0.679  5.957  100.0  1.8026   24  666.0
# 405  25.94060  0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666.0
# 410  25.94060  0.0  18.10     0  0.597  5.757  100.0  1.4130   24  666.0
# 414  25.94060  0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666.0
# ..        ...  ...    ...   ...    ...    ...    ...     ...  ...    ...
# 217   0.07013  0.0  13.89     0  0.550  6.642   85.1  3.4211    5  276.0
# 180   0.06588  0.0   2.46     0  0.488  7.765   83.3  2.7410    3  193.0
# 503   0.06076  0.0  11.93     0  0.573  6.976   91.0  2.1675    1  273.0
# 88    0.05660  0.0   3.41     0  0.489    NaN   86.3  3.4217    2  270.0
# 505   0.04741  0.0  11.93     0  0.573  6.030   80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 418     20.2   16.45  20.62   8.8
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# 414     20.2   88.27  36.98   7.0
# ..       ...     ...    ...   ...
# 217     16.4  392.78   9.69  28.7
# 180     17.8  395.56   7.56  39.8
# 503     21.0  396.90   5.64  23.9
# 88      17.8  396.90   5.50  23.6
# 505     21.0  396.90   7.88  11.9
#
# [240 rows x 14 columns]

# %% [markdown]
# ```{admonition} 1-2
# **1-1에서 사용한 데이터에서 RM 중앙값으로 해당 컬럼의 결측치를 대체하라
# 그리고 해당 컬럼의 결측치 대치 전후의 표준편차 차이의 절댓값을 소숫점 이하 3째자리 까지 구하라**
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv')

df = df.sort_values(['CRIM'],ascending=False)
df2 = df.copy()
df2 = df2.head(10)
dm  = df2['CRIM'].min()
# dm

df['CRIM'] = np.where(df['CRIM']>dm,dm,df['CRIM'])
# df
df = df[df['AGE']>=80]
# -------------------------------------------------
dfa = df.copy()
dfb = df.copy()

dfa['RM'] = dfa['RM'].fillna(dfa['RM'].median())
a = dfa['RM'].std()
b = dfb['RM'].std()

print(round(abs(a-b),3))
# Out:
# 0.013

# %% [markdown]
# ```{admonition} 1-3
# **주어진 Dataset의 DIS 평균으로 부터 1.5 * 표준편차를 벗어나는 영역을 이상치라고 판단하고
# DIS 컬럼의 이상치들의 합을 구하여라.**
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv')

stdd = df['DIS'].std()
md = df['DIS'].mean()
cond1 = md + 1.5*stdd
cond2 = md - 1.5*stdd
df2 = df.copy()
df3 = df.copy()
df2 = df2[df2['DIS']>cond1]
a = df2['DIS'].sum()
df3 =df3[df3['DIS']<cond2]
b = df3['DIS'].sum()
print(a+b)
# Out:
# 404.4101

# %% [markdown]
# # 작업 2유형

# %% [markdown]
# ```{attention}
# 데이터 설명 : e-commerce 배송의 정시 도착여부 (1: 정시배송 0 : 정시미배송)
# x_train: https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_train.csv
# y_train: https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_train.csv
# x_test: https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_test.csv
# x_label(평가용) : https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_test.csv
# 데이터 출처 :https://www.kaggle.com/datasets/prachi13/customer-analytics (참고, 데이터 수정)
#
# **x_train 데이터로 학습한 모델을 x_test에 적용하여 예측한 결과를 제출하라. 평가 지표는 f1_score이다.**
# ```

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_test.csv")


display(x_train.head())
display(y_train.head())
# Out:
#      ID Warehouse_block Mode_of_Shipment Customer_care_calls  Customer_rating  \
# 0  6045               A           Flight                   4                3
# 1    44               F             Ship                   3                1
# 2  7940               F             Road                   4                1
# 3  1596               F             Ship                   4                3
# 4  4395               A           Flight                   5                3
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  266                5               high      F
# 1                  174                2                low      M
# 2                  154               10               high      M
# 3                  158                3             medium      F
# 4                  175                3                low      M
#
#    Discount_offered  Weight_in_gms
# 0                 5           1590
# 1                44           1556
# 2                10           5674
# 3                27           1207
# 4                 7           4833
#      ID  Reached.on.Time_Y.N
# 0  6045                    0
# 1    44                    1
# 2  7940                    1
# 3  1596                    1
# 4  4395                    1

# %%
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/shipping/X_test.csv")
# 1. 데이터 탐색
# print(x_train.info())
# print(x_test.info())
# print(y_train.info())

# 2. 데이터 전처리
x_train_drop = x_train.drop(columns = ['ID'])
x_test_drop = x_test.drop(columns = ['ID'])
y = y_train['Reached.on.Time_Y.N']

x_train_dummies = pd.get_dummies(x_train_drop)
x_test_dummies = pd.get_dummies(x_test_drop)
x_test_dummies = x_test_dummies[x_train_dummies.columns]

# 3. 모델링
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

x_train, x_val, y_train, y_val = train_test_split(x_train_dummies,y,test_size=0.2,stratify = y,random_state=42)
rf = RandomForestClassifier(random_state=23)
rf.fit(x_train,y_train)

# 4. 성능확인
y_pred = rf.predict(x_val)
acc = accuracy_score(y_val,y_pred)
# print(acc)

# 5. 제출
y_result = rf.predict_proba(x_train_dummies)
y_result
# pd.DataFrame({'result':y_result[:,1]}).to_csv('007002940.csv',index=False)

# %% [markdown]
# # 작업 3유형

# %% [markdown]
# ```{attention}
# 어느 호수에서 잡은 물고기 122마리 길이 데이터(자체제작)
# **DataUrl = https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p3_1.csv**
# ```

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p3_1.csv')
df.head(5)
# Out:
#      fish   height
# 0  fish_1  33.74cm
# 1  fish_2  31.64cm
# 2  fish_3  27.49cm
# 3  fish_4  31.43cm
# 4  fish_5  27.56cm

# %% [markdown]
# ```{admonition} 3-1-a
# **122마리의 height 평균값을 m(미터) 단위로 소숫점 이하 5자리까지 실수 값만 출력하라**
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p3_1.csv')

# df.info()
df['height'] = df['height'].str.replace('cm','').astype('float')
# df.info()
df['height'] = df['height']/100
# df
print(round(df['height'].mean(),5))
# Out:
# 0.29951

# %% [markdown]
# ```{admonition} 3-1-b
# **모집단의 평균 길이가 30cm 인지 확인하려 일표본 t 검정을 시행하여 확인하려한다. 검정통계량을 소숫점 이하 3째자리까지 구하여라**
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p3_1.csv')
df['height'] = df['height'].str.replace('cm','').astype('float')
import scipy.stats as stats
from scipy.stats import shapiro

stat,pvalue = shapiro(df['height'])
# print(stat,pvalue)
# stat,pval=stats.wilcoxon(df['height']-30,alternative='two-sided')
# print(stat,pval)
stat,pval = stats.ttest_1samp(df['height'],popmean=30,alternative='two-sided')
# print(stat,pval)
print(round(stat,3))
# Out:
# -0.217

# %% [markdown]
# ```{admonition} 3-1-c
# **위의 통계량에 대한 p-값을 구하고 (반올림하여 소숫점 이하 3째자리), 유의수준 0.05하에서 귀무가설과 대립가설중 유의한 가설을 하나를 선택하시오(귀무/대립)**
# ```

# %%
stat,pvalue = shapiro(df['height'])
# print(stat,pvalue)
# stat,pval=stats.wilcoxon(df['height']-30,alternative='two-sided')
# print(stat,pval)
stat,pval = stats.ttest_1samp(df['height'],popmean=30,alternative='two-sided')
# print(stat,pval)
print(round(pval,3))
# Out:
# 0.829

# %% [markdown]
# ```{attention}
# 조사결과 70%의 성인 남성이 3년 동안에 적어도 1번 치과를 찾는다고 할때, 21명의 성인 남성이 임의로 추출되었다고 하자.
# ```

# %% [markdown]
# ```{admonition} 3-2 - a
# **21명 중 16명 미만이 치과를 찾았을 확률(반올림하여 소숫점 이하 3자리)**
# ```

# %%
from scipy.stats import binom

n = 21
p = 0.7
k = 16
prob = binom.cdf(k-1,n,p)
print(round(prob,3))
# Out:
# 0.637

# %% [markdown]
# ```{admonition} 3-2 - b
# **적어도 19명이 치과를 찾았을 확률(반올림하여 소숫점 이하 3자리)**
# ```

# %%
from scipy.stats import binom

n = 21
p = 0.7
k = 19
prob = 1- binom.cdf(k-1,n,p)
print(round(prob,3))
# Out:
# 0.027
